# %%
# !pip install instabot

# %% [markdown]
# ### That means 'too many requests'. I'll go to sleep for 5 minutes.
#
# ----------------------------
#
# ### https://stackoverflow.com/a/72203259/11493297

# %%
# Login

from instabot import Bot
import getpass
from PIL import Image

try:
    import shutil
    shutil.rmtree('config')
except:
    pass

user = ['_____.___alone___._____', 'vix.bot']
passwd = getpass.getpass('Enter Password : ')

bot = Bot()
bot.login(username = user[1], password = passwd)

# 2023-04-07 20:55:57,540 - INFO - LOGIN FLOW! Just logged-in: True
# Out:
# Enter Password : ········
# 2023-04-07 21:17:09,292 - INFO - Instabot version: 0.117.0 Started
# 2023-04-07 21:17:09,298 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-04-07 21:17:09,681 - ERROR - Request returns 429 error!
# 2023-04-07 21:17:10,842 - ERROR - Request returns 429 error!
# 2023-04-07 21:17:12,747 - INFO - Logged-in successfully as 'vix.bot'!
# 2023-04-07 21:17:12,749 - INFO - LOGIN FLOW! Just logged-in: True
# 2023-04-07 21:17:14,891 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2023-04-07 21:17:14,892 - INFO - Full Response: <Response [404]>
# 2023-04-07 21:17:14,893 - INFO - Response Text: <!DOCTYPE html>
# <html lang="None" class="no-js not-logged-in ">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>
#                   Page Not Found &bull; Instagram
#                 </title>
#
#
# ...

# %%
# DM

bot.send_message("Message sent via python", [user[0]])
# Out:
# True

# %%
def make_square(im, min_size=256, fill_color=(255,255,255,0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGB', (size, size), fill_color)
    
#     https://stackoverflow.com/a/63873375/11493297
    new_im = new_im.convert("RGB")
    
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

choose = 'img-aTZJkMVPHMMM55L3yvpcqh3E.png'
path = f'images/{choose}'

# choose = 'bol-vo-rahe-hai-par-shabd-humare-hain-dubeyji-writer.jpg'
# path = 'to_upload/bol-vo-rahe-hai-par-shabd-humare-hain-dubeyji-writer.png'

test_image = Image.open(path)
new_image = make_square(test_image)

try:
    import os
    os.mkdir('to_upload')
except:
    pass

path = f'to_upload/{choose}.jpg'
new_image.save(path)
path
# Out:
# 'to_upload/img-aTZJkMVPHMMM55L3yvpcqh3E.png.jpg'

# %% [markdown]
# ## Photo 'xyz.png' is not uploaded
#
# ------------------
#
# ### https://stackoverflow.com/a/63873375/11493297

# %%
cap = '🔥 This image is created by OpenAI API and uploaded using InstaBot package written in python language 💡' 
bot.upload_photo(path, caption = cap)

try:
    import shutil
    shutil.rmtree('config')
except:
    pass
# Out:
# FOUND: w:512 h:512 r:1.0
# 2023-04-07 21:19:10,540 - INFO - Photo 'to_upload/img-aTZJkMVPHMMM55L3yvpcqh3E.png.jpg' is uploaded.

# %%
from PIL import Image
import urllib2 as urllib
import io

fd = urllib.urlopen("https://oaidalleapiprodscus.blob.core.windows.net/private/org-Z0Thpnv9nStuAJE5dKhhHd8U/user-Vpy5qef3GlLla8gB3yTDThit/img-p6GlPvpe6DfBV2SLLpJ6Tu8h.png?st=2023-05-07T15%3A12%3A32Z&se=2023-05-07T17%3A12%3A32Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-05-07T16%3A12%3A32Z&ske=2023-05-08T16%3A12%3A32Z&sks=b&skv=2021-08-06&sig=eyS9mS3BicZ9aEtQV4HYsSCK8Yc2Pm6FM77xBw4oCiY%3D")
image_file = io.BytesIO(fd.read())
im = Image.open(image_file)
im
